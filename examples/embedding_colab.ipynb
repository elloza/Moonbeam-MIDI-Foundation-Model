# %% [markdown]
# # Moonbeam Embedding Example
# This notebook shows how to obtain an embedding for a MIDI file using the Moonbeam MIDI Foundation Model.

# %%
# !git clone https://github.com/AIM-QMUL/Moonbeam-MIDI-Foundation-Model.git
# %cd Moonbeam-MIDI-Foundation-Model

# %%
# !pip install .
# !pip install src/llama_recipes/transformers_minimal/.
# !pip install huggingface_hub

# %%
# !wget https://huggingface.co/guozixunnicolas/moonbeam-midi-foundation-model/resolve/main/moonbeam_309M.pt
# !wget https://huggingface.co/guozixunnicolas/moonbeam-midi-foundation-model/resolve/main/moonbeam_839M.pt

# %%
# !wget -O sample.mid https://archive.org/download/midifiles-bach/bwv846.mid

# %%
# !python examples/extract_embedding.py sample.mid moonbeam_839M.pt

# Smaller model
# !python examples/extract_embedding.py sample.mid moonbeam_309M.pt --config src/llama_recipes/configs/model_config_309M.json
